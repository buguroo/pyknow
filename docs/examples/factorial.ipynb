# %% [markdown]
# http://www.cs.upc.edu/~bejar/ia/material/laboratorio/clips/CLIPS-snippets-eng.pdf
# Page 5 - Computing the factorial

# %%
from pyknow import *
#watch()

# %%
class Factorial(Fact):
    pass

# %%
def isint(x):
    return isinstance(x, int)
    
class ComputeFactorial(KnowledgeEngine):    
    @Rule(Factorial('x' << P(isint),
                    'y' << P(isint)))
    def factorial(self, x, y):
        self.declare(Factorial(x + 1, (x + 1) * y))

# %%
cf = ComputeFactorial()
cf.deffacts(Factorial(1, 1))
cf.reset()
cf.run(6)
cf.facts
# Out:
# <f-0>: InitialFact()
# <f-1>: Factorial(1, 1)
# <f-2>: Factorial(2, 2)
# <f-3>: Factorial(3, 6)
# <f-4>: Factorial(4, 24)
# <f-5>: Factorial(5, 120)
# <f-6>: Factorial(6, 720)
# <f-7>: Factorial(7, 5040)

# %%
cf.matcher.show_network()
